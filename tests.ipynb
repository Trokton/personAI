# %%
import numpy as np
import matplotlib.pyplot as plt

rand = np.random.RandomState(42)

mean = [0, 0]
cov =[[1, 4], [34, 34]]
x = rand.multivariate_normal(mean, cov, 100)
x.shape
# Out:
# /var/folders/py/dvhytgn16c19hxj_msm_kpx00000gn/T/ipykernel_5518/2423592113.py:8: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   x = rand.multivariate_normal(mean, cov, 100)
# (100, 2)

# %%
# %matplotlib inline
plt.scatter(x[:,0], x[:,1])
